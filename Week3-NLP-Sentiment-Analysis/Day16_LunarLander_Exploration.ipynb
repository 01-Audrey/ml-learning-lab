# %%
==================================================
ML LEARNING JOURNEY - DAY 16
==================================================
Week: 3 of 24
Day: 16 of 168
Date: November 13, 2025 (Tuesday)
Topic: Lunar Lander Environment Exploration
Overall Progress: 9.5%

Week 3 Progress:
✅ Day 15: RL Theory & Setup
🔄 Day 16: Environment Exploration (TODAY!)
⬜ Day 17: Implement DQN Architecture
⬜ Day 18: Training & Optimization
⬜ Day 19: Visualization & Analysis
⬜ Day 20: Web Deployment
⬜ Day 21: Documentation & GitHub

Progress: 14% (1/7 days)
==================================================

🎯 Today's Learning Objectives:
1. Understand Lunar Lander environment specs
2. Explore state space (8 dimensions)
3. Test all 4 actions (do nothing, left, main, right)
4. Analyze reward function in detail
5. Establish baseline with random agent
6. Visualize environment behavior

📚 Today's Structure:
   Part 1 (1.5h): Environment Setup & Testing
   Part 2 (1.5h): State/Action Space Analysis
   Part 3 (2h): Random Agent Baseline
   Part 4 (1h): Data Collection & Visualization

🎯 SUCCESS CRITERIA:
   ✅ Successfully render Lunar Lander environment
   ✅ Understand all 8 state variables
   ✅ Test each of 4 actions
   ✅ Collect baseline performance data
   ✅ Create reward distribution plot
   ✅ Ready for DQN implementation tomorrow!

==================================================

# %%
---

# 🚀 PART 1: ENVIRONMENT SETUP & FIRST LOOK

# %%
## 1.1 Import Required Libraries

# %%
pip install gymnasium pygame numpy matplotlib pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium
#   Downloading gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting pygame
#   Downloading pygame-2.6.1-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in c:\users\audrey\appdata\roaming\python\python313\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\audrey\appdata\roaming\python\python313\site-packages (3.10.6)
# Requirement already satisfied: pandas in c:\users\audrey\appdata\roaming\python\python313\site-packages (2.3.2)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from gymnasium) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\audrey\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading gymnasium-1.2.2-py3-none-any.whl (952 kB)
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 952.1/952.1 kB 13.0 MB/s  0:00:00
# Downloading pygame-2.6.1-cp313-cp313-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 10.6/10.6 MB 70.0 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, pygame, cloudpickle, gymnasium
#
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ---------- ----------------------------- 1/4 [pygame]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ---------------------------------------- 4/4 [gymnasium]
#
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-1.2.2 pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import deque
import time

# Set random seeds for reproducibility
np.random.seed(42)

print("✅ Libraries imported successfully!")
print(f"Gymnasium version: {gym.__version__}")
# Out:
# ✅ Libraries imported successfully!
# Gymnasium version: 1.2.2
